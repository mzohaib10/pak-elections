# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../pak_election_data_cleaned_20180124.csv')
# Out:
# /Users/zohaib/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#     id_no     na  na_value                      na_name   sr  \
# 0    43.0    NaN        13          Na-13 Abbottabad-II  5.0
# 1  5201.0    1.0         1              NA-1 PESHAWAR-I  1.0
# 2  5307.0    NaN        22  NA-22 SWAT-II, Old Swat-III  3.0
# 3   719.0  195.0       195             NA-195 Quetta-II  1.0
# 4   108.0    NaN        18                    NW-18 Dir  6.0
#
#           candidate_name        party  party1  party_93  nnparty ...   winner  \
# 0  Mr.Mohammad Azam Khan          IND    39.0       NaN     88.0 ...      NaN
# 1     Haji Dost Mohammad          IND   138.0     102.0     75.0 ...      NaN
# 2  Mr. Abdul Jabbar Khan          IND    39.0      39.0     88.0 ...      NaN
# 3         Mr.Abdul Wahid          IND    39.0       NaN     88.0 ...      NaN
# 4             Majidullah  Independent     2.0       NaN      NaN ...      NaN
#
#    ndivision  nzones_20  nregions_12  nregions_11  nprov  party_2013  \
# ...

# %%
df_meta = pd.read_csv('../map_attributes_2002_2008_2013.csv')

# %%
df_meta.head()
# Out:
#    year na_number  na_value                na_name  \
# 0  2002      NA-1         1        NA-1 PESHAWAR-I
# 1  2002     NA-10        10        NA-10 Mardan-II
# 2  2002    NA-100       100   NA-100 Gujranwala-VI
# 3  2002    NA-101       101  NA-101 Gujranwala-VII
# 4  2002    NA-102       102     NA-102 Hafizabad-I
#
#                         winner                       winner_party  \
# 0              Mr.Shabir Ahmad  Muttahidda Majlis-e-Amal Pakistan
# 1       Maulana Muhammad Qasim  Muttahidda Majlis-e-Amal Pakistan
# 2          Chaudhry Bilal Ijaz         Pakistan Muslim League (Q)
# 3        Mr.Hamid Nasir Chatta         Pakistan Muslim League (J)
# 4  Chaudhry Mehdi Hasan Bhatti         Pakistan Muslim League (Q)
#
#                        runnerup                           runnerup_party  \
# 0        Mr.Usman Bashir Bilour                     Awami National Party
# 1             Mr.Rahim Dad Khan  Pakistan Peoples Party Parliamentarians
# ...

# %%
df_meta.groupby('year').describe()
# Out:
#               year    na_value  victory_margin     turn_out
# count   816.000000  816.000000      807.000000   809.000000
# mean   2007.666667  136.500000       18.515527    49.949886
# std       4.499671   78.567262       16.973482   113.126115
# min    2002.000000    1.000000        0.086517     0.000000
# 25%    2002.000000   68.750000        5.709844    37.428936
# 50%    2008.000000  136.500000       13.231085    46.924685
# 75%    2013.000000  204.250000       26.045593    56.000000
# max    2013.000000  272.000000       92.142013  3243.000000
